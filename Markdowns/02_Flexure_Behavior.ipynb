# %% [markdown]
# <div style="width:100%; background-color:#181818; color:#f1f1f1; padding:30px 0; text-align:center; border-radius:10px;">
#   <h3 style="color:#ffffff; margin:0 0 8px 0;"><b>Flexure I: Section Behavior</b></h3>
#   <p style="margin:4px 0;"><b>Authors:</b> Msc. Ing. Carlos Andr&eacute;s Celi S&aacute;nchez &middot; Nicol&aacute;s Mora Bowen &middot; Juan Sebasti&aacute;n Baquero</p>
#   <p style="margin:4px 0;"><b>Course:</b> Reinforced Concrete Design II</p>
#   <p style="margin:4px 0; color:#d1d5db;">How an applied moment becomes strain, internal force, curvature, cracking, and ductility.</p>
#   <img src="assets/authors.png" alt="Course authors" width="900" style="max-width:100%; margin-top:22px; border-radius:10px;">
# </div>

# %% [markdown]
# ## Class question
#
# A beam does not resist a moment because a formula says it can. It resists because concrete and reinforcing steel develop compatible strains, those strains create stresses, the stresses form internal resultants, and the resultants create an internal couple. This class follows that chain before we introduce the design shortcuts used in the next class.
#
# The governing question is: **what sequence of physical events occurs as moment increases, and which event determines whether the member is safe, usable, and ductile?**

# %% [markdown]
# ### What this class must establish
#
# This is a mechanics class, not a calendar written as a table. By the end, a section should be readable in four mutually consistent languages: **geometry** (where the material is), **strain** (how it deforms), **stress** (what each material develops), and **resultants** (the forces and moment that equilibrate the applied action). The calculation in the next class is merely a compact way of solving these four descriptions together.
#
# The discussion moves from sectional equilibrium to the linear kinematics of bending, then from constitutive laws to numerical integration of stress. It follows the response through first cracking, yield, and compression deterioration. At every stage, we will distinguish three questions that are often confused: **does the section have strength, is it stiff enough for service, and does its deformation sequence provide ductility?**

# %% [markdown]
# ### Required strength and available strength
#
# The member demand is the factored effect obtained from the structural model and applicable load combinations. For flexure, the basic strength check is expressed as:
#
# <div style="margin:18px 0; padding:14px; background:#f8fafc; color:#1e293b; text-align:center; font-family:Georgia,serif; font-size:1.15em;">&phi;M<sub>n</sub> &ge; M<sub>u</sub></div>
#
# Here, <i>M<sub>u</sub></i> is not a property of the beam: it comes from loading, span, continuity, and analysis. <i>M<sub>n</sub></i> is not the same as the factored moment: it is the section's nominal internal capacity. The factor <i>&phi;</i> converts that nominal claim into design strength by recognizing uncertainty and the desired failure mode.
#
# Keeping demand and resistance separate prevents a common mistake: changing reinforcement cannot fix a wrong tributary load, and changing a load combination cannot repair a brittle section.
#
# For a simply supported member under a uniform factored line load <i>w<sub>u</sub></i>, the maximum factored moment is <i>M<sub>u</sub> = w<sub>u</sub>L<sup>2</sup>/8</i>; support continuity, concentrated loads, frame action, second-order effects, and lateral combinations change that demand model but not the distinction. The structural analysis supplies a distribution of <i>M<sub>u</sub>(x)</i> along the member. The section analysis asks whether each critical section has compatible internal resultants that can resist its local value.
#
# Keep dimensions visible. If force is in kN and length in m, moment is kN-m; if force is in N and length in mm, moment is N-mm. A factor of one thousand quietly misplaced between analysis and section design can make a plausible-looking but useless answer.

# %% [markdown]
# ### Sign convention is a physical statement
#
# Positive bending normally compresses the top fibres and places the bottom reinforcement in tension; negative bending reverses those roles. The sign is not cosmetic. It identifies where cracking begins, which bars must be developed, which face needs confinement or continuity reinforcement, and which construction joint or support zone becomes critical.
#
# When reviewing any moment diagram, ask four questions: Which face is in compression? Which face is in tension? Where must force enter or leave the reinforcement? Is the assumed detail physically available at that location?

# %% [markdown]
# <figure style="margin:28px 0; text-align:center;"><img src="assets/02_flexure_behavior/fig-01.png" alt="Laboratory flexural test of a beam" width="650" style="max-width:100%; border-radius:8px;"><figcaption style="margin-top:10px; color:#475569; font-size:0.9em;">Figure 1. Flexure is observed through deformation and cracking, not only through a final capacity number.</figcaption></figure>

# %% [markdown]
# ## 1. The internal flexural mechanism
#
# External loads produce shear and bending moment along a member. At a section, the external moment must be balanced by an internal couple. Concrete is efficient in compression; reinforcement carries the tensile force after cracking. The essential equilibrium statement is therefore:
#
# <div style="margin:18px 0; text-align:center; font-family:Georgia,serif; font-size:1.12em; color:#1e293b;">C = T &nbsp;&nbsp;&middot;&nbsp;&nbsp; M = Tz = Cz</div>
#
# The lever arm <i>z</i> is not automatically equal to <i>d</i>. It depends on the location of both resultants, which in turn depends on the strain and stress fields. This is why section behavior must precede the familiar design equation.
#
# The distinction also separates bending from shear. Bending changes the magnitude and relative location of normal-force resultants over a section; shear is associated with the change of bending moment along the member, <i>V = dM/dx</i>, and produces a different stress field. A flexural calculation is not a waiver for shear design, but a correct moment diagram tells us where both mechanisms must be examined.

# %% [markdown]
# <figure style="margin:28px 0; text-align:center;"><img src="assets/02_flexure_behavior/fig-06.png" alt="Reinforced concrete section, strain distribution, stress distribution, and internal forces" width="1100" style="max-width:100%;"><figcaption style="margin-top:10px; color:#475569; font-size:0.9em;">Figure 2. The four simultaneous views of one section: geometry, strain compatibility, stress distribution, and internal resultants.</figcaption></figure>

# %% [markdown]
# ### The minimum vocabulary
#
# | Quantity | Physical meaning | Why it matters |
# |---|---|---|
# | <i>b, h, d</i> | Width, total depth, and effective depth | Geometry controls compression area and lever arm. |
# | <i>A<sub>s</sub>, A'<sub>s</sub></i> | Tension and compression reinforcement area | Steel amount changes force capacity and ductility. |
# | <i>c, x</i> | Neutral-axis depth | Connects strain compatibility to the compression zone. |
# | <i>f'<sub>c</sub>, f<sub>y</sub></i> | Concrete strength and steel yield strength | Material strengths are not interchangeable with stresses. |
# | <i>&epsilon;<sub>c</sub>, &epsilon;<sub>s</sub></i> | Concrete and steel strains | Strain identifies yield, crushing, and deformation control. |
# | <i>&rho;</i> | Reinforcement ratio | A compact measure of how heavily the section is reinforced. |
#
# Every symbol should be introduced through a sketch of the section. A notation list without its physical location is a dictionary with the pages shuffled.
#
# Two ratios will recur. The reinforcement ratio is <i>rho = A<sub>s</sub>/(bd)</i>; it compares tensile steel to the available concrete compression geometry. The mechanical ratio <i>omega = rho f<sub>y</sub>/f'<sub>c</sub></i> further compares steel yield stress to concrete compressive strength. They are useful because different-sized beams can have similar sectional behavior when their geometry and material ratios are similar. They do not replace a compatibility calculation, especially with multiple steel layers or nonrectangular sections.

# %% [markdown]
# ## 2. Compatibility turns geometry into mechanics
#
# Three assumptions form the classical flexure model:
#
# 1. Plane sections remain plane after bending. The strain profile is linear through the depth.
# 2. Reinforcing steel and surrounding concrete have the same strain at their shared level; bond is sufficient to enforce compatibility.
# 3. Stresses are obtained from the constitutive response of each material.
#
# The first assumption creates a linear strain diagram. The second locates the steel strain from similar triangles. The third converts strain into stress and then into force. If any of these links fails - for example through bond failure, local crushing, or inadequate development length - the simple section model stops describing the real member.

# %% [markdown]
# ### Constitutive response is the bridge
#
# Concrete has a nonlinear compression response, very limited tensile strength, and time-dependent deformation. Reinforcing steel is commonly represented by an elastic branch followed by yielding. The important classroom point is not to memorize one curve: it is to know which part of the curve is active at a given stage and what that implies for stiffness, crack width, force redistribution, and warning before failure.
#
# For preliminary response studies, an elastic-perfectly-plastic steel model and a calibrated concrete compression model are useful. For design strength, the next notebook will introduce the code-compatible equivalent compression block.

# %% [markdown]
# ## 3. The moment-curvature story
#
# Moment is a sectional force effect; curvature measures how rapidly the beam bends. Curvature is associated with the slope of the strain diagram. A moment-curvature curve reveals changes that a single nominal moment cannot show: initial stiffness, crack formation, steel yield, strain hardening or concrete softening, and usable deformation capacity.
#
# A practical interpretation follows five stations:
#
# 1. **Uncracked elastic response**: concrete carries both compression and limited tension; stiffness is high.
# 2. **Cracking**: the extreme tension fibre reaches its tensile limit; stiffness drops abruptly.
# 3. **Cracked elastic response**: steel increasingly carries tension while concrete carries compression.
# 4. **Steel yield**: curvature increases rapidly with comparatively modest moment increase; ductility becomes visible.
# 5. **Compression-controlled deterioration**: crushing or strength loss limits usable curvature.

# %% [markdown]
# <figure style="margin:28px 0; text-align:center;"><img src="assets/02_flexure_behavior/fig-07.png" alt="Moment-curvature response showing cracking, yielding, and post-yield points" width="900" style="max-width:100%;"><figcaption style="margin-top:10px; color:#475569; font-size:0.9em;">Figure 3. A moment-curvature response distinguishes cracking, yield, and post-yield deformation capacity.</figcaption></figure>

# %% [markdown]
# ### Cracking is a transition, not collapse
#
# The cracking moment is the flexural effect at which the extreme concrete tension fibre reaches its modulus of rupture. Before this point, an uncracked gross-section model can be useful. After it, the tensile contribution of concrete across the main crack cannot be treated as a durable flexural mechanism.
#
# Cracking matters because stiffness changes. Deflection, redistribution in indeterminate systems, crack width, vibration, and the apparent demand on adjacent elements can all be influenced by that transition. A member may be far from strength failure and already be a serviceability problem.

# %% [markdown]
# ### Yield, crushing, and preferred failure
#
# A tension-controlled section allows the reinforcement to yield before the concrete compression zone crushes. This produces visible deformation and energy dissipation. A heavily reinforced section can gain nominal strength while losing the warning and rotational capacity that make a structure reliable in reality.
#
# The balanced condition is a reference point where tensile steel reaches yield as concrete reaches its limiting compression strain. It is not the target for ordinary beam design. The desirable side of the boundary is one with adequate tensile strain and a stable, ductile sequence of response.

# %% [markdown]
# ## 4. Parameter effects: strength, stiffness, and ductility are not the same variable
#
# | Change | Nominal strength | Cracked stiffness | Deformation capacity | Design interpretation |
# |---|---|---|---|---|
# | Increase <i>A<sub>s</sub></i> | Usually increases | Often increases | Usually decreases | More steel is not automatically better. |
# | Increase <i>d</i> | Strong increase | Strong increase | Often maintained or improved | Depth is an efficient flexural resource. |
# | Increase <i>b</i> | Increases | Increases | May improve | Helpful when architectural width is available. |
# | Increase <i>f'<sub>c</sub></i> | Moderate increase | Increases | Must be checked | Stronger concrete can be less forgiving in compression. |
# | Increase <i>f<sub>y</sub></i> | Increases | Limited direct effect | Can reduce curvature capacity | Strength gain must be read through strain compatibility. |
# | Add A'<sub>s</sub> | Can increase | Can improve long-term response | Can improve | Useful for ductility, long-term effects, and congestion-sensitive design. |

# %% [markdown]
# ## 5. Equilibrium is an integral statement
#
# The familiar pair <i>C = T</i> is the special result for a section under pure bending with no net axial force. Its origin is more general. On any cross-section, the normal stress field <i>sigma(y)</i> produces an axial resultant and a bending resultant:
#
# <div style="margin:18px 0; padding:14px; background:#f8fafc; color:#1e293b; text-align:center; font-family:Georgia,serif; font-size:1.12em;">N = integral[sigma dA] &nbsp;&nbsp;&nbsp; and &nbsp;&nbsp;&nbsp; M = integral[sigma y dA]</div>
#
# The coordinate <i>y</i> is measured from a stated reference axis. The first integral asks whether the compression and tension forces balance; the second asks whether their locations create exactly the moment demanded at that section. Discrete reinforcement enters the same equations as concentrated areas: a bar at level <i>y<sub>i</sub></i> contributes <i>f<sub>s,i</sub>A<sub>s,i</sub></i> to axial force and <i>f<sub>s,i</sub>A<sub>s,i</sub>y<sub>i</sub></i> to moment.
#
# For a nonprestressed beam with negligible axial load, the signed equilibrium equation becomes <i>C<sub>c</sub> + C<sub>s</sub> - T<sub>s</sub> = 0</i>. A reported capacity is credible only if that residual is essentially zero at the proposed neutral-axis depth. Moment is then calculated about any convenient axis; changing the axis changes the individual terms but not the final resultant moment when force equilibrium is satisfied.

# %% [markdown]
# ### Kinematics: why plane sections give a linear strain field
#
# Let <i>u(x)</i> be the axial displacement of a reference fibre and let <i>v(x)</i> be the transverse displacement. Under the Euler-Bernoulli description, a cross-section rotates but does not warp. The axial displacement at depth <i>y</i> can therefore be written as <i>u(x,y) = u<sub>0</sub>(x) - y theta(x)</i>. Differentiating with respect to <i>x</i> gives:
#
# <div style="margin:18px 0; padding:14px; background:#f8fafc; color:#1e293b; text-align:center; font-family:Georgia,serif; font-size:1.12em;">epsilon(x,y) = epsilon<sub>0</sub>(x) - y kappa(x)</div>
#
# where <i>epsilon<sub>0</sub></i> is the strain of the reference fibre and <i>kappa = d theta/dx</i> is curvature. Thus the strain diagram is linear because it is a kinematic consequence of plane sections, not because concrete happens to have a linear stress law. In pure bending of a homogeneous elastic beam, the neutral axis is where <i>epsilon = 0</i> and the diagram can be written as <i>epsilon(y) = kappa y</i> after choosing that axis.
#
# In a reinforced concrete section, the neutral axis must be found rather than presumed. It migrates as cracking removes concrete tension, as steel yields, and as the compression law becomes nonlinear. The straight strain line remains the compatibility hypothesis; the stress distribution below it may be curved, stepped, or partly zero.

# %% [markdown]
# ### Similar triangles locate every material strain
#
# Take the neutral axis at depth <i>c</i> from the extreme compression fibre and let the extreme concrete strain be <i>epsilon<sub>c</sub></i>. For a tension layer at effective depth <i>d</i>, compatibility gives:
#
# <div style="margin:18px 0; padding:14px; background:#f8fafc; color:#1e293b; text-align:center; font-family:Georgia,serif; font-size:1.12em;">epsilon<sub>s</sub> = epsilon<sub>c</sub>(d - c)/c &nbsp;&nbsp;&nbsp; and &nbsp;&nbsp;&nbsp; kappa = epsilon<sub>c</sub>/c</div>
#
# For compression reinforcement at depth <i>d'</i>, use <i>epsilon'<sub>s</sub> = epsilon<sub>c</sub>(c - d')/c</i> when that layer lies inside the compression zone. These are not design formulas; they are geometry. Once <i>c</i> and one endpoint strain are specified, the strain at every bar follows immediately.
#
# This is the central diagnostic of flexure: a shallow neutral axis produces a large tension-steel strain and usually a ductile sequence; a deep neutral axis produces small tensile strain and moves the section toward compression-controlled behavior. The code later translates that mechanical observation into strength-reduction provisions.

# %% [markdown]
# ## 6. From strain to stress: material laws
#
# For reinforcing steel, the first useful model is elastic-perfectly-plastic. With elastic modulus <i>E<sub>s</sub></i>, yield strain is <i>epsilon<sub>y</sub> = f<sub>y</sub>/E<sub>s</sub></i>. The stress rule is <i>f<sub>s</sub> = E<sub>s</sub> epsilon<sub>s</sub></i> while the absolute stress remains below <i>f<sub>y</sub></i>; after idealized yield, its magnitude is limited to <i>f<sub>y</sub></i>. A more refined model may include strain hardening, but it cannot be selected merely because it produces a larger answer.
#
# Concrete is fundamentally different. In compression, its stress rises nonlinearly, reaches a peak, and then softens as damage localizes. In tension, its tensile strength is small relative to its compressive strength; after a dominant flexural crack forms, tension is transmitted mainly by steel and by local tension-stiffening mechanisms between cracks. Therefore the exact stress field for a service or research analysis is obtained from <i>f<sub>c</sub>(epsilon)</i> and integrated over the compressed region, not assumed rectangular from the outset.
#
# A crucial separation: a **constitutive model** describes material response, while the equivalent compression block introduced later is a calibrated strength-design representation of the resultant compression force. Treating the latter as the actual stress distribution is convenient, but physically false.

# %% [markdown]
# ### Section analysis as a one-variable root-finding problem
#
# For a specified curvature or a specified extreme concrete strain, the unknown controlling the section is often <i>c</i>. Choose a trial <i>c</i>; obtain all strains from compatibility; convert them to stresses with the material laws; integrate concrete stress and sum bar forces; then evaluate the axial residual:
#
# <div style="margin:18px 0; padding:14px; background:#f8fafc; color:#1e293b; text-align:center; font-family:Georgia,serif; font-size:1.12em;">R(c) = C<sub>c</sub>(c) + sum[C<sub>s</sub>(c)] - sum[T<sub>s</sub>(c)] - N<sub>applied</sub></div>
#
# The compatible section state occurs where <i>R(c) = 0</i>. Only after locating that state should moment be assembled from the same force set. This is the mathematical engine behind a fibre-section moment-curvature analysis. It also exposes bad results: if a spreadsheet reports a moment without a force residual, it has not demonstrated equilibrium.
#
# A robust hand calculation mirrors the later algorithm: bracket a plausible neutral axis, calculate the residual at both ends, narrow the interval, and retain a table of <i>c</i>, strains, stresses, forces, residual, and moment. The computer will accelerate the iteration; it must not conceal the mechanics.

# %% [markdown]
# ## 7. Before cracking: elastic flexure and transformed sections
#
# At very low moment, if concrete tension is retained in the model, both materials are approximately elastic and curvature follows the familiar relation <i>M = EI kappa</i>. The complication is that steel and concrete have different elastic moduli. A transformed section replaces steel area by an equivalent concrete area using the modular ratio <i>n = E<sub>s</sub>/E<sub>c</sub></i>. For a tension bar, the transformed contribution is commonly <i>nA<sub>s</sub></i> when the displaced concrete is neglected at this level of approximation.
#
# From the transformed geometry, calculate the centroidal neutral axis and transformed second moment of area <i>I<sub>tr</sub></i>. The elastic strain and stress follow from <i>epsilon = kappa y</i>, <i>f<sub>c</sub> = E<sub>c</sub>kappa y</i>, and <i>f<sub>s</sub> = E<sub>s</sub>kappa y</i>. The steel stress is therefore approximately <i>n</i> times the concrete stress at the same level, which is precisely why the transformed area works.
#
# This stage is useful for physical interpretation, but it should not be extended past its domain. Once a flexural crack crosses the tensile concrete, gross-section stiffness ceases to represent the local cracked section.

# %% [markdown]
# ### First cracking and the meaning of M<sub>cr</sub>
#
# For an uncracked elastic section, the extreme-fibre tension is <i>f<sub>t</sub> = My/I<sub>g</sub></i>. If the tensile limit is represented by the modulus of rupture <i>f<sub>r</sub></i>, the corresponding first-cracking estimate is:
#
# <div style="margin:18px 0; padding:14px; background:#f8fafc; color:#1e293b; text-align:center; font-family:Georgia,serif; font-size:1.12em;">M<sub>cr</sub> = f<sub>r</sub>I<sub>g</sub>/y<sub>t</sub></div>
#
# Here <i>I<sub>g</sub></i> is the gross concrete second moment of area and <i>y<sub>t</sub></i> is the distance from its centroid to the tensile extreme fibre. This expression estimates the onset of a tensile crack under the ideal elastic stress field. It does not mean that all tension disappears everywhere at that instant, nor that the member has lost safety.
#
# After cracking, stiffness drops because the tensile side no longer contributes as a continuous concrete area across the governing crack. Between cracks, bond causes concrete to share some tension with steel; this tension-stiffening effect matters in refined serviceability work, but it does not restore the gross-section stiffness.

# %% [markdown]
# ### Cracked elastic section: a second equilibrium problem
#
# In the simplest cracked-section idealization, tensile concrete is ignored. Let <i>x</i> be the cracked elastic neutral-axis depth from the compression face. For a rectangular section with one tension layer, force equilibrium of the elastic stress triangles leads to the transformed-area condition:
#
# <div style="margin:18px 0; padding:14px; background:#f8fafc; color:#1e293b; text-align:center; font-family:Georgia,serif; font-size:1.12em;">b x(x/2) = nA<sub>s</sub>(d - x)</div>
#
# The left term is the first moment of the triangular concrete compression region about its neutral axis; the right term is the transformed steel first moment. Solving it locates <i>x</i>. Then the cracked transformed inertia is <i>I<sub>cr</sub> = bx<sup>3</sup>/3 + nA<sub>s</sub>(d-x)<sup>2</sup></i>. Since <i>I<sub>cr</sub></i> is usually far below <i>I<sub>g</sub></i>, curvature and deflection rise sharply after cracking for the same moment.
#
# The formula is not a substitute for a code serviceability procedure. Its value here is diagnostic: it shows algebraically why reinforcement location matters so much. Moving the same steel farther from the compression face increases both its lever arm and its contribution to cracked inertia.

# %% [markdown]
# ## 8. Curvature links section response to member deformation
#
# Curvature is not an abstract graph axis. For small rotations, <i>kappa = d theta/dx</i> and approximately <i>kappa = d<sup>2</sup>v/dx<sup>2</sup></i>. Member rotation is the area under the curvature diagram, <i>theta = integral[kappa dx]</i>; transverse displacement follows a second integration. Thus a local change in sectional stiffness propagates into deflection, drift, redistribution, and plastic rotation.
#
# In an elastic prismatic region, <i>kappa = M/(EI)</i>. Once cracking or yielding occurs, neither <i>E</i> nor <i>I</i> is globally constant. A moment-curvature analysis replaces one constant stiffness with a sequence of compatible section states. Its tangent slope, <i>dM/dkappa</i>, is the instantaneous flexural stiffness. A steep curve is stiff; a long nearly horizontal post-yield branch is a source of rotation capacity, provided degradation and instability do not intervene.
#
# For a member with nonuniform moment, it is wrong to multiply one curvature by the full span. The curvature must be associated with its location and integrated along the actual moment diagram. This becomes indispensable when estimating rotations in plastic-hinge regions.

# %% [markdown]
# ### Yield is a strain event; ductility is a deformation ratio
#
# Steel yield begins when <i>epsilon<sub>s</sub> = epsilon<sub>y</sub></i>, not when a chart looks flat. The corresponding section state has a yield curvature <i>kappa<sub>y</sub></i>. Later, under increasing curvature, a section may reach an ultimate curvature <i>kappa<sub>u</sub></i> when concrete crushing, bar fracture, confinement loss, or another limiting mechanism is reached. A basic curvature-ductility index is <i>mu<sub>kappa</sub> = kappa<sub>u</sub>/kappa<sub>y</sub></i>.
#
# This ratio is useful but incomplete. Structures dissipate energy and accommodate drift through member and connection rotations. Plastic curvature must occur over a finite length, and the effective plastic-hinge length depends on moment gradient, bar development, shear response, confinement, cyclic deterioration, and boundary conditions. A section can have an attractive <i>mu<sub>kappa</sub></i> but produce poor member ductility if bar slip, shear failure, or instability terminates the response first.
#
# The safe conceptual sequence is therefore: material strain capacity -> sectional curvature capacity -> rotational capacity -> system displacement demand. Skipping any arrow is how a beautiful moment capacity becomes an ugly failure mechanism.

# %% [markdown]
# ## 9. Read parameter effects through dimensionless ratios
#
# The reinforcement ratio <i>rho = A<sub>s</sub>/(bd)</i> is more revealing than steel area alone because it compares steel to the concrete compression geometry available to balance it. Increasing <i>rho</i> generally deepens the neutral axis. From compatibility, a deeper <i>c</i> reduces <i>epsilon<sub>s</sub> for a given compression strain, which is the mechanical reason heavily reinforced sections tend to lose tension-controlled behavior.
#
# Effective depth has a particularly strong role. At a fixed reinforcement ratio and comparable material response, internal force scales roughly with <i>bd</i>, while lever arm scales with <i>d</i>; flexural resistance therefore grows approximately with <i>bd<sup>2</sup></i>. This squared depth effect explains why modest increases in effective depth can be more efficient than adding steel, while also benefiting stiffness. It is a scaling insight, not permission to ignore cover, shear, anchorage, or architectural constraints.
#
# Increasing concrete strength changes both the compression resultant and the compression strain behavior. Increasing yield strength raises the stress that steel may develop, but if the same layout is used it can also alter the neutral axis and curvature sequence. The engineer should ask which variable controls the problem: force, stiffness, crack width, rotation capacity, reinforcement congestion, or constructibility. There is no universal direction called 'better'.

# %% [markdown]
# ## 10. A complete section state, written without a design shortcut
#
# Consider a rectangular beam section with one tension layer, no axial force, and a trial compression strain <i>epsilon<sub>c</sub></i>. The unknown neutral-axis depth <i>c</i> defines the entire strain diagram. The tension-steel strain follows from compatibility, <i>epsilon<sub>s</sub> = epsilon<sub>c</sub>(d-c)/c</i>. A steel constitutive rule returns <i>f<sub>s</sub></i>; a concrete constitutive rule gives the compression stress over the interval from the top fibre to <i>c</i>.
#
# The concrete resultant is not guessed. For width <i>b</i>, it is <i>C<sub>c</sub> = b integral from 0 to c of f<sub>c</sub>(epsilon(y)) dy</i>. Its line of action is located by the first moment of that same stress field: <i>y<sub>C</sub> = [b integral from 0 to c of y f<sub>c</sub>(epsilon(y)) dy] / C<sub>c</sub></i>. The steel force is <i>T<sub>s</sub> = A<sub>s</sub>f<sub>s</sub></i>. The compatible equilibrium state satisfies <i>C<sub>c</sub> - T<sub>s</sub> = 0</i>.
#
# Once equilibrium closes, the internal moment about the compression resultant is <i>M = T<sub>s</sub>(d-y<sub>C</sub>)</i>. This derivation shows exactly what later code equations compress into a few symbols. It also clarifies why a compression block has two separate jobs: estimate the magnitude of <i>C<sub>c</sub></i> and locate its resultant.
#
# If the steel has not yielded, the solution is coupled because <i>f<sub>s</sub></i> depends on <i>c</i>. If it has yielded, its stress may be nearly constant but the concrete resultant still changes with <i>c</i>. In neither case is it defensible to select the lever arm before determining the strain state.

# %% [markdown]
# ### Building a moment-curvature curve by hand before coding it
#
# A hand-built curve is the best audit trail for a later numerical implementation. Select a sequence of increasing controlling strains or curvatures. At each station, solve force equilibrium for <i>c</i>, then record the resulting moment. The table below is the actual state record; it is more important than a smooth plot.
#
# | Step | Prescribed quantity | Solve for | Record | Mechanical interpretation |
# |---|---|---|---|---|
# | 1 | Small epsilon<sub>c</sub> or kappa | c | M, steel stress, residual | Nearly elastic response |
# | 2 | Tension reaches f<sub>r</sub> | c | M<sub>cr</sub>, stiffness change | First flexural crack |
# | 3 | Larger kappa | c | M, I<sub>sec</sub> = M/kappa | Cracked elastic response |
# | 4 | epsilon<sub>s</sub> = epsilon<sub>y</sub> | c | M<sub>y</sub>, kappa<sub>y</sub> | Steel yield |
# | 5 | Limiting compression strain | c | M<sub>u</sub>, kappa<sub>u</sub> | Compression limit or deterioration onset |
#
# At each row, check units explicitly: strains and curvature have dimensions of 1/length; stress times area gives force; force times lever arm gives moment. Also record the force residual, not merely its rounded display value. The curve becomes trustworthy when the transition points have a mechanical explanation and the residual remains acceptably small.

# %% [markdown]
# ### What the ideal section model cannot decide by itself
#
# Plane sections and perfect bond are powerful idealizations, but they do not certify a member. Near supports, point loads, lap splices, openings, abrupt depth changes, disturbed regions, and anchorage zones, the strain field can depart materially from the one-dimensional flexure assumption. A section calculation also does not prove that shear strength, development length, bar buckling restraint, confinement, durability, construction tolerances, or connection behavior are adequate.
#
# Cyclic loading adds further complications: crack opening and closing, bond deterioration, stiffness and strength degradation, pinching, low-cycle fatigue, and the interaction of axial load with flexure. The monotonic moment-curvature curve remains a foundation, not a complete seismic member model. The correct habit is to name the assumptions beside the result; hiding them is not rigor.
#
# This boundary is especially important when teaching. The goal is not to make the beam appear more complicated than it is. The goal is to know exactly which physical mechanism each equation represents and which mechanisms are being excluded from the equation.

# %% [markdown]
# ## Worked example: manual record and code handoff
#
# The manual examples from the course reference will remain the common benchmark for this course. In this notebook they establish the behavior and expected checkpoints; no solution code is included here by design.
#
# ### Example handoff template
#
# | Item | What your later code should receive or return |
# |---|---|
# | Inputs | Section dimensions, reinforcement layout, cover, material models, and imposed curvature or moment steps. |
# | State variables | Neutral-axis depth, strain at each reinforcement layer, concrete compression resultant, steel forces, curvature. |
# | Outputs | Moment-curvature points, cracking estimate, yield point, nominal-capacity point, and governing strain state. |
# | Checks | Force equilibrium, moment equilibrium, compatible strains, units, and monotonic loading path. |
#
# <div style="margin:18px 0; padding:18px; border:2px dashed #64748b; border-radius:8px; color:#334155; background:#f8fafc;"><b>Code handoff - reserved for the instructor.</b><br>Insert your Python implementation here after the manual example has been discussed. Keep the manual target values above the code cell so that the model is verified against mechanics, not merely against its own output.</div>

# %% [markdown]
# ## Closing synthesis
#
# Flexural design begins with a sequence, not a coefficient: **moment creates strain; strain creates stress; stress creates internal force; internal force creates resistance; and the deformation sequence determines ductility.**
#
# The next class converts this mechanics into ACI design decisions: the equivalent compression block, strength-reduction factor, reinforcement limits, singly and doubly reinforced beams, and sections with flanges.
